# %%
import pandas as pd

# %%
version = '01.2022'

# %% [markdown]
# ## 1. Extract all compound IDs that belong to a Chemical Probes Set
#
# Compound sets per data source:
# ```
# Bromodomains chemical toolbox, 277
# Chemical Probes.org, 408
# Gray Laboratory Probes, 240
# MLP probes, 14 --> Legacy compound set
# Open Science Probes, 213
# High-quality chemical probes, 395 --> Turn into a boolean label
# Nature Chemical Biology Probes, 19 --> Legacy compound set
# opnMe Portal, 219
# Probe Miner (suitable probes), 227
# Protein methyltransferases chemical toolbox, 278
# SGC Probes, 28
# Tool Compound Set, 19`
# Natural product-based probes and drugs, 445
# JUMP-Target 1 Compound Set, 443
# JUMP-Target 2 Compound Set, 444
# Chemical Probes for Understudied Kinases, 409
# ```

# %%
compound2compoundset = pd.read_csv(f"csv_dumps/{version}/compoundtocompoundset.csv", sep=",", header=0, usecols=['compound_id', 'compoundset_id'])
compoundsets = (
    pd.read_csv(
        f"csv_dumps/{version}/compoundset.csv",
        sep=",",
        header=0,
        usecols=['compoundsetid', 'name', 'source_url'])
    .rename(columns={'name' : 'source'})
)

# %%
compoundsets[compoundsets.source.str.contains("Natural") | compoundsets.source.str.contains("JUMP") | compoundsets.source.str.contains("Chemical Probes")]
# Out:
#     compoundsetid                                    source  \
# 55            409  Chemical Probes for Understudied Kinases
# 62            408                       Chemical Probes.org
# 68            443                JUMP-Target 1 Compound Set
# 72            444                JUMP-Target 2 Compound Set
# 73            445    Natural product-based probes and drugs
#
#                                            source_url
# 55  https://pubs.acs.org/doi/10.1021/acs.jmedchem....
# 62                     http://new.chemicalprobes.org/
# 68      https://jump-cellpainting.broadinstitute.org/
# 72      https://jump-cellpainting.broadinstitute.org/
# 73  https://pubs.rsc.org/en/content/articlelanding...

# %%
probes_compoundsetids = [277, 408, 240, 213, 395, 219, 227, 278, 28, 19, 445, 443, 444, 409]

compound2compoundset = (
    compound2compoundset.merge(
        compoundsets[['compoundsetid', 'source', 'source_url']],
        left_on='compoundset_id',
        right_on='compoundsetid',
        how='inner'
    )
    # Select compounds coming from Probes data sources
    .query('compoundset_id in @probes_compoundsetids')
    .drop(['compoundsetid', 'compoundset_id'], axis=1)
)

print(compound2compoundset.shape[0])
compound2compoundset.head()
# Out:
# 5944
#        compound_id                         source  \
# 13596        30108  Bromodomains chemical toolbox
# 13597        29511  Bromodomains chemical toolbox
# 13598        32473  Bromodomains chemical toolbox
# 13599         7226  Bromodomains chemical toolbox
# 13600        26115  Bromodomains chemical toolbox
#
#                                               source_url
# 13596  https://www.nature.com/articles/s41467-019-096...
# 13597  https://www.nature.com/articles/s41467-019-096...
# 13598  https://www.nature.com/articles/s41467-019-096...
# 13599  https://www.nature.com/articles/s41467-019-096...
# 13600  https://www.nature.com/articles/s41467-019-096...

# %% [markdown]
# # 🧐 Question: If probe in different sources, do we duplicate or want the id to be unique? Unique ID

# %% [markdown]
# ## 2.1 Pair compound IDs with probes IDs

# %%
probes = (
    pd.read_csv(
        f"csv_dumps/{version}/probe.csv",
        sep=",",
        header=0,
        usecols=['probeid', 'compound_id', 'control', 'origin_id'],
        dtype={'probeid':'int64', 'control':'category'})
    .rename(columns={'probeid':'probe_id', 'origin_id':'origin'})
)
probes.head(5)
# Out:
#    probe_id  compound_id      origin control
# 0     38210        45800  calculated     NaN
# 1     37607        21003  calculated   ['1']
# 2     37579        21668  calculated   ['1']
# 3     37581        24527  calculated   ['1']
# 4     36559        45465  calculated   ['1']

# %%
probes.control.value_counts()
# Out:
# ['1']             1037
# ['BI-6354']          6
# ['No control']       6
# ['FM-743']           5
# ['TP-030n']          5
#                   ...
# ['BI-1374']          1
# ['BI-1282']          1
# ['BI-0900']          1
# ['BI-0449']          1
# ['BI-5525']          1
# Name: control, Length: 141, dtype: int64

# %%
'''
# Controls are read as strings
def str_to_list(X):
    if isinstance(X, str):
        arr = X.strip('[]').split(',')
        arr = [e.strip("''") for e in arr]
        return arr
    return None
    
    
probes['control'] = probes['control'].apply(lambda X: str_to_list(X))

probes = probes.explode('control')
'''
# Out:
# '\n# Controls are read as strings\ndef str_to_list(X):\n    if isinstance(X, str):\n        arr = X.strip(\'[]\').split(\',\')\n        arr = [e.strip("\'\'") for e in arr]\n        return arr\n    return None\n    \n    \nprobes[\'control\'] = probes[\'control\'].apply(lambda X: str_to_list(X))\n\nprobes = probes.explode(\'control\')\n'

# %%
# There are 13 compounds not present in the probes dataset
# All coming from 'High-quality chemical probes'

df = compound2compoundset.merge(
    probes,
    on='compound_id',
    how='left'
)

df.head(5)
# Out:
#    compound_id                         source  \
# 0        30108  Bromodomains chemical toolbox
# 1        30108  Bromodomains chemical toolbox
# 2        29511  Bromodomains chemical toolbox
# 3        29511  Bromodomains chemical toolbox
# 4        29511  Bromodomains chemical toolbox
#
#                                           source_url  probe_id        origin  \
# 0  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 1  https://www.nature.com/articles/s41467-019-096...   39678.0  experimental
# 2  https://www.nature.com/articles/s41467-019-096...   35250.0  experimental
# 3  https://www.nature.com/articles/s41467-019-096...   35459.0  experimental
# 4  https://www.nature.com/articles/s41467-019-096...   39684.0  experimental
#
#        control
# 0  ['D-Moses']
# 1  ['D-Moses']
# 2  ['GSK4028']
# 3  ['GSK4028']
# 4  ['GSK4028']

# %% [markdown]
# ## 2.2 Extract compound name and inchikey

# %%
compounds = (
    pd.read_csv(
        f"csv_dumps/{version}/compound.csv",
        sep=",",
        header=0,
        usecols=['compoundid', 'name', 'inchikey'])
    .rename(columns={'compoundid':'compound_id', 'name':'compound_name', 'inchikey':'inchiKey'})
)

# %%
df = df.merge(
    compounds,
    on='compound_id',
    how='left'
)

df.head(5)
# Out:
#    compound_id                         source  \
# 0        30108  Bromodomains chemical toolbox
# 1        30108  Bromodomains chemical toolbox
# 2        29511  Bromodomains chemical toolbox
# 3        29511  Bromodomains chemical toolbox
# 4        29511  Bromodomains chemical toolbox
#
#                                           source_url  probe_id        origin  \
# 0  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 1  https://www.nature.com/articles/s41467-019-096...   39678.0  experimental
# 2  https://www.nature.com/articles/s41467-019-096...   35250.0  experimental
# 3  https://www.nature.com/articles/s41467-019-096...   35459.0  experimental
# 4  https://www.nature.com/articles/s41467-019-096...   39684.0  experimental
#
#        control compound_name                     inchiKey
# 0  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# 1  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# 2  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N
# 3  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N
# 4  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N

# %% [markdown]
# ## 3. Extract target associated with probe

# %%
# First extract target_id
probes2targets = pd.read_csv(f"csv_dumps/{version}/probetobasetarget.csv",
                             sep=",",
                             header=0,
                             usecols=['probe_id', 'basetarget_id'])
                             

df = df.merge(
    probes2targets,
    on='probe_id',
    how='left'
)

# %%
print("Counts per source:")

df.groupby('source').count()
# Out:
# Counts per source:
#                                              compound_id  source_url  \
# source
# Bromodomains chemical toolbox                        177         177
# Chemical Probes for Understudied Kinases              94          94
# Chemical Probes.org                                 1363        1363
# Gray Laboratory Probes                               184         184
# High-quality chemical probes                        1557        1557
# JUMP-Target 1 Compound Set                           393         393
# JUMP-Target 2 Compound Set                           393         393
# Natural product-based probes and drugs               523         523
# Nature Chemical Biology Probes                       112         112
# Open Science Probes                                  291         291
# Probe Miner (suitable probes)                       3332        3332
# Protein methyltransferases chemical toolbox           83          83
# SGC Probes                                           409         409
# opnMe Portal                                         135         135
#
#                                              probe_id  origin  control  \
# source
# Bromodomains chemical toolbox                     177     177       99
# Chemical Probes for Understudied Kinases           94      94       26
# Chemical Probes.org                              1363    1363      420
# Gray Laboratory Probes                            184     184        0
# High-quality chemical probes                     1547    1547      515
# JUMP-Target 1 Compound Set                        129     129       14
# JUMP-Target 2 Compound Set                        129     129       14
# Natural product-based probes and drugs             30      30        2
# Nature Chemical Biology Probes                    112     112        3
# Open Science Probes                               291     291      291
# Probe Miner (suitable probes)                    3332    3332     1058
# Protein methyltransferases chemical toolbox        83      83        5
# SGC Probes                                        409     409      147
# opnMe Portal                                      135     135      119
#
#                                              compound_name  inchiKey  \
# source
# Bromodomains chemical toolbox                          177       177
# Chemical Probes for Understudied Kinases                94        94
# Chemical Probes.org                                   1363      1363
# Gray Laboratory Probes                                 184       184
# High-quality chemical probes                          1557      1557
# JUMP-Target 1 Compound Set                             393       393
# JUMP-Target 2 Compound Set                             393       393
# Natural product-based probes and drugs                 523       523
# Nature Chemical Biology Probes                         112       112
# Open Science Probes                                    291       291
# Probe Miner (suitable probes)                         3332      3332
# Protein methyltransferases chemical toolbox             83        83
# SGC Probes                                             409       409
# opnMe Portal                                           135       135
#
#                                              basetarget_id
# source
# Bromodomains chemical toolbox                          177
# Chemical Probes for Understudied Kinases                94
# Chemical Probes.org                                   1336
# Gray Laboratory Probes                                 180
# High-quality chemical probes                          1508
# JUMP-Target 1 Compound Set                             125
# JUMP-Target 2 Compound Set                             125
# Natural product-based probes and drugs                  30
# Nature Chemical Biology Probes                          73
# Open Science Probes                                    283
# Probe Miner (suitable probes)                         3331
# Protein methyltransferases chemical toolbox             63
# SGC Probes                                             389
# opnMe Portal                                           132

# %%
# Then extract target name

base_targets = (
    pd.read_csv(
        f"csv_dumps/{version}/basetarget.csv",
        sep=",",
        header=0,
        usecols=['basetargetid', 'name', 'gene_name'])
    .rename(columns={'basetargetid':'basetarget_id', 'name':'target_name', 'gene_name':'target_symbols'})
)

# %%
df = df.merge(
    base_targets,
    on='basetarget_id',
    how='left'
)

df.head(10)
# Out:
#    compound_id                         source  \
# 0        30108  Bromodomains chemical toolbox
# 1        30108  Bromodomains chemical toolbox
# 2        30108  Bromodomains chemical toolbox
# 3        30108  Bromodomains chemical toolbox
# 4        30108  Bromodomains chemical toolbox
# 5        30108  Bromodomains chemical toolbox
# 6        29511  Bromodomains chemical toolbox
# 7        29511  Bromodomains chemical toolbox
# 8        29511  Bromodomains chemical toolbox
# 9        29511  Bromodomains chemical toolbox
#
#                                           source_url  probe_id        origin  \
# 0  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 1  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 2  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 3  https://www.nature.com/articles/s41467-019-096...   39678.0  experimental
# 4  https://www.nature.com/articles/s41467-019-096...   39678.0  experimental
# 5  https://www.nature.com/articles/s41467-019-096...   39678.0  experimental
# 6  https://www.nature.com/articles/s41467-019-096...   35250.0  experimental
# 7  https://www.nature.com/articles/s41467-019-096...   35250.0  experimental
# 8  https://www.nature.com/articles/s41467-019-096...   35250.0  experimental
# 9  https://www.nature.com/articles/s41467-019-096...   35459.0  experimental
#
#        control compound_name                     inchiKey  basetarget_id  \
# 0  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 1  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        40818.0
# 2  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        42795.0
# 3  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 4  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        40818.0
# 5  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        42795.0
# 6  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N        33454.0
# 7  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N        40818.0
# 8  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N        42795.0
# 9  ['GSK4028']       GSK4027  VZAFGXCWAWRULT-UONOGXRCSA-N        33454.0
#
#                              target_name target_symbols
# 0        Histone acetyltransferase KAT2B          KAT2B
# 1        Histone acetyltransferase KAT2A          KAT2A
# 2  Histone acetyltransferase KAT2A/KAT2B    KAT2A,KAT2B
# 3        Histone acetyltransferase KAT2B          KAT2B
# 4        Histone acetyltransferase KAT2A          KAT2A
# 5  Histone acetyltransferase KAT2A/KAT2B    KAT2A,KAT2B
# 6        Histone acetyltransferase KAT2B          KAT2B
# 7        Histone acetyltransferase KAT2A          KAT2A
# 8  Histone acetyltransferase KAT2A/KAT2B    KAT2A,KAT2B
# 9        Histone acetyltransferase KAT2B          KAT2B

# %%
# Extract uniprot ID from target

basetarget2target = (
    pd.read_csv(
        f"csv_dumps/{version}/targettobasetarget.csv",
        sep=",",
        header=0,
        usecols=['basetarget_id', 'target_id']))

targets = (
    pd.read_csv(
        f"csv_dumps/{version}/target.csv",
        sep=",",
        header=0,
        usecols=['targetid', 'organism_id', 'uniprotid'])
    .rename(columns={'targetid': 'target_id', 'uniprotid':'uniprot_ids'})
)

# %%
df = (
    # Map from basetarget to target
    df.merge(
        basetarget2target,
        on='basetarget_id',
        how='left'
    )
    # Extract organism_id and uniprot_ids from target
    .merge(
        targets,
        on='target_id',
        how='left'
    )
    # Select human as organism (organism_id = [5428, 2832])
    .query('organism_id in [5428, 2832]')
)

# %%
# Split and explode the uniprot_ids columns

df['uniprot_id'] = df['uniprot_ids'].apply(lambda X: X.split(','))
df = df.explode('uniprot_id')

# %%
df.head()
# Out:
#    compound_id                         source  \
# 0        30108  Bromodomains chemical toolbox
# 1        30108  Bromodomains chemical toolbox
# 2        30108  Bromodomains chemical toolbox
# 3        30108  Bromodomains chemical toolbox
# 5        30108  Bromodomains chemical toolbox
#
#                                           source_url  probe_id        origin  \
# 0  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 1  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 2  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 3  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 5  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
#
#        control compound_name                     inchiKey  basetarget_id  \
# 0  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 1  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 2  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 3  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 5  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        40818.0
#
#                        target_name target_symbols  target_id  organism_id  \
# 0  Histone acetyltransferase KAT2B          KAT2B   130124.0       2832.0
# 1  Histone acetyltransferase KAT2B          KAT2B   108370.0       2832.0
# 2  Histone acetyltransferase KAT2B          KAT2B   108371.0       2832.0
# 3  Histone acetyltransferase KAT2B          KAT2B   108372.0       2832.0
# 5  Histone acetyltransferase KAT2A          KAT2A   130257.0       2832.0
#
#   uniprot_ids uniprot_id
# 0      Q92831     Q92831
# 1      Q92831     Q92831
# 2      Q92831     Q92831
# 3      Q92831     Q92831
# 5      Q92830     Q92830

# %% [markdown]
# ## 4. Extract scores

# %%
scores = (
    pd.read_csv(
        f"csv_dumps/{version}/compoundtargetscore.csv",
        sep=",",
        header=0,
        usecols=['compound_id', 'basetarget_id', 'percentage', 'score_id'])
    # Filter with only score_ids of interest
    .query('score_id in [1, 5, 6, 7]')
)

df_s = df.merge(
        scores,
        on=['basetarget_id', 'compound_id'],
        how='left'
)

# %%
df_s
# Out:
#        compound_id                         source  \
# 0            30108  Bromodomains chemical toolbox
# 1            30108  Bromodomains chemical toolbox
# 2            30108  Bromodomains chemical toolbox
# 3            30108  Bromodomains chemical toolbox
# 4            30108  Bromodomains chemical toolbox
# ...            ...                            ...
# 73107        48310         Gray Laboratory Probes
# 73108        48310         Gray Laboratory Probes
# 73109        48310         Gray Laboratory Probes
# 73110        48310         Gray Laboratory Probes
# 73111        48310         Gray Laboratory Probes
#
#                                               source_url  probe_id  \
# 0      https://www.nature.com/articles/s41467-019-096...   35251.0
# 1      https://www.nature.com/articles/s41467-019-096...   35251.0
# 2      https://www.nature.com/articles/s41467-019-096...   35251.0
# 3      https://www.nature.com/articles/s41467-019-096...   35251.0
# 4      https://www.nature.com/articles/s41467-019-096...   35251.0
# ...                                                  ...       ...
# 73107        http://graylab.dana-farber.org/probes.html#   35546.0
# 73108        http://graylab.dana-farber.org/probes.html#   35546.0
# 73109        http://graylab.dana-farber.org/probes.html#   35546.0
# 73110        http://graylab.dana-farber.org/probes.html#   35546.0
# 73111        http://graylab.dana-farber.org/probes.html#   35546.0
#
#              origin      control compound_name                     inchiKey  \
# 0      experimental  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# 1      experimental  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# 2      experimental  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# 3      experimental  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# 4      experimental  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# ...             ...          ...           ...                          ...
# 73107  experimental          NaN         dBRD9  AIOCFZJGGGEWDK-UHFFFAOYSA-N
# 73108  experimental          NaN         dBRD9  AIOCFZJGGGEWDK-UHFFFAOYSA-N
# 73109  experimental          NaN         dBRD9  AIOCFZJGGGEWDK-UHFFFAOYSA-N
# 73110  experimental          NaN         dBRD9  AIOCFZJGGGEWDK-UHFFFAOYSA-N
# 73111  experimental          NaN         dBRD9  AIOCFZJGGGEWDK-UHFFFAOYSA-N
#
#        basetarget_id                       target_name target_symbols  \
# 0            33454.0   Histone acetyltransferase KAT2B          KAT2B
# 1            33454.0   Histone acetyltransferase KAT2B          KAT2B
# 2            33454.0   Histone acetyltransferase KAT2B          KAT2B
# 3            33454.0   Histone acetyltransferase KAT2B          KAT2B
# 4            40818.0   Histone acetyltransferase KAT2A          KAT2A
# ...              ...                               ...            ...
# 73107        32700.0  Bromodomain-containing protein 9           BRD9
# 73108        32700.0  Bromodomain-containing protein 9           BRD9
# 73109        32700.0  Bromodomain-containing protein 9           BRD9
# 73110        32700.0  Bromodomain-containing protein 9           BRD9
# 73111        32700.0  Bromodomain-containing protein 9           BRD9
#
#        target_id  organism_id uniprot_ids uniprot_id  score_id  percentage
# 0       130124.0       2832.0      Q92831     Q92831       7.0        50.0
# 1       108370.0       2832.0      Q92831     Q92831       7.0        50.0
# 2       108371.0       2832.0      Q92831     Q92831       7.0        50.0
# 3       108372.0       2832.0      Q92831     Q92831       7.0        50.0
# 4       130257.0       2832.0      Q92830     Q92830       7.0        30.0
# ...          ...          ...         ...        ...       ...         ...
# 73107   124444.0       2832.0      Q9H8M2     Q9H8M2       6.0         0.0
# 73108   124444.0       2832.0      Q9H8M2     Q9H8M2       7.0        39.6
# 73109   124445.0       2832.0      Q9H8M2     Q9H8M2       5.0        92.5
# 73110   124445.0       2832.0      Q9H8M2     Q9H8M2       6.0         0.0
# 73111   124445.0       2832.0      Q9H8M2     Q9H8M2       7.0        39.6
#
# [73112 rows x 17 columns]

# %%
df_s["probesDrugsScore"] = df_s.apply(lambda X: X.percentage if X.score_id == 7 else None, axis=1)
df_s['probeMinerScore'] = df_s.apply(lambda X: X.percentage if X.score_id == 1 else None, axis=1)
df_s['scoreInCells'] = df_s.apply(lambda X: X.percentage if X.score_id == 5 else None, axis=1)
df_s['scoreInOrganisms'] = df_s.apply(lambda X: X.percentage if X.score_id == 6 else None, axis=1)

# %%
# Right now I have duplicated rows due to:
# several data sources evidencing the same assoc +
# exploded uniprot ids +
# I have to coalesce the score rows

# %%
df = df_s.copy()

# %% [markdown]
# ## 5. Extract MoA

# %%
moas = (
    pd.read_csv(
        f"csv_dumps/{version}/compoundaction.csv",
        sep=",",
        header=0,
        usecols=['compound_id', 'target_id', 'actiontype_id'])
)

# %%
df = df.merge(
        moas,
        on=['target_id', 'compound_id'],
        how='left'
)

# %%
df.head()
# Out:
#    compound_id                         source  \
# 0        30108  Bromodomains chemical toolbox
# 1        30108  Bromodomains chemical toolbox
# 2        30108  Bromodomains chemical toolbox
# 3        30108  Bromodomains chemical toolbox
# 4        30108  Bromodomains chemical toolbox
#
#                                           source_url  probe_id        origin  \
# 0  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 1  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 2  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 3  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 4  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
#
#        control compound_name                     inchiKey  basetarget_id  \
# 0  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 1  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 2  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 3  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 4  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        40818.0
#
#                        target_name  ... organism_id  uniprot_ids  uniprot_id  \
# 0  Histone acetyltransferase KAT2B  ...      2832.0       Q92831      Q92831
# 1  Histone acetyltransferase KAT2B  ...      2832.0       Q92831      Q92831
# 2  Histone acetyltransferase KAT2B  ...      2832.0       Q92831      Q92831
# 3  Histone acetyltransferase KAT2B  ...      2832.0       Q92831      Q92831
# 4  Histone acetyltransferase KAT2A  ...      2832.0       Q92830      Q92830
#
#   score_id percentage  probesDrugsScore  probeMinerScore  scoreInCells  \
# 0      7.0       50.0              50.0              NaN           NaN
# 1      7.0       50.0              50.0              NaN           NaN
# 2      7.0       50.0              50.0              NaN           NaN
# 3      7.0       50.0              50.0              NaN           NaN
# 4      7.0       30.0              30.0              NaN           NaN
#
#    scoreInOrganisms  actiontype_id
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 6. Map to drugId

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = (SparkSession.builder
    .appName('spark')
    .getOrCreate())

# %%
drug_idx = (
    spark.read.parquet('/Users/irene/Documents/dev/pyspark/22.04.1/molecule')
    .select(col('id').alias('drugId'), 'inchiKey')
    .toPandas()
)

# %%
df = (
    # Get drugId
    df.merge(
        drug_idx,
        on='inchiKey',
        how='left')
)


df.head()
# Out:
#    compound_id                         source  \
# 0        30108  Bromodomains chemical toolbox
# 1        30108  Bromodomains chemical toolbox
# 2        30108  Bromodomains chemical toolbox
# 3        30108  Bromodomains chemical toolbox
# 4        30108  Bromodomains chemical toolbox
#
#                                           source_url  probe_id        origin  \
# 0  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 1  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 2  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 3  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
# 4  https://www.nature.com/articles/s41467-019-096...   35251.0  experimental
#
#        control compound_name                     inchiKey  basetarget_id  \
# 0  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 1  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 2  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 3  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        33454.0
# 4  ['D-Moses']       L-Moses  MSFPLTWUFWOKBX-IFXJQAMLSA-N        40818.0
#
#                        target_name  ... uniprot_ids  uniprot_id  score_id  \
# 0  Histone acetyltransferase KAT2B  ...      Q92831      Q92831       7.0
# 1  Histone acetyltransferase KAT2B  ...      Q92831      Q92831       7.0
# 2  Histone acetyltransferase KAT2B  ...      Q92831      Q92831       7.0
# 3  Histone acetyltransferase KAT2B  ...      Q92831      Q92831       7.0
# 4  Histone acetyltransferase KAT2A  ...      Q92830      Q92830       7.0
#
#   percentage probesDrugsScore  probeMinerScore  scoreInCells  \
# 0       50.0             50.0              NaN           NaN
# 1       50.0             50.0              NaN           NaN
# 2       50.0             50.0              NaN           NaN
# 3       50.0             50.0              NaN           NaN
# 4       30.0             30.0              NaN           NaN
#
#    scoreInOrganisms  actiontype_id  drugId
# 0               NaN            NaN     NaN
# 1               NaN            NaN     NaN
# 2               NaN            NaN     NaN
# 3               NaN            NaN     NaN
# 4               NaN            NaN     NaN
#
# [5 rows x 23 columns]

# %%
df = df.astype({
    'probe_id': 'Int64',
    'basetarget_id': 'Int64',
    'target_id': 'Int64',
    'organism_id': 'Int64',
    'score_id': 'Int64'
})

# %%
df.to_csv(f'output/{version}/chemprobes_{version}_1.tsv', sep='\t', header=True, index=False)

# %%
df.iloc[0]
# Out:
# compound_id                                                     30108
# source                                  Bromodomains chemical toolbox
# source_url          https://www.nature.com/articles/s41467-019-096...
# probe_id                                                        35251
# origin                                                   experimental
# control                                                   ['D-Moses']
# compound_name                                                 L-Moses
# inchiKey                                  MSFPLTWUFWOKBX-IFXJQAMLSA-N
# basetarget_id                                                   33454
# target_name                           Histone acetyltransferase KAT2B
# target_symbols                                                  KAT2B
# target_id                                                      130124
# organism_id                                                      2832
# uniprot_ids                                                    Q92831
# uniprot_id                                                     Q92831
# score_id                                                            7
# percentage                                                       50.0
# probesDrugsScore                                                 50.0
# probeMinerScore                                                   NaN
# scoreInCells                                                      NaN
# scoreInOrganisms                                                  NaN
# actiontype_id                                                     NaN
# drugId                                                            NaN
# Name: 0, dtype: object

# %% [markdown]
# ## 7. Build final dataset

# %%
data = spark.read.csv(f'output/{version}/chemprobes_{version}_1.tsv', sep='\t', header=True)

# %% [markdown]
# All posible URLs
# ```
# +-------------------------------------------+---------------------------------------------------------------+
# |source                                     |source_url                                                     |
# +-------------------------------------------+---------------------------------------------------------------+
# |Probe Miner (suitable probes)              |http://probeminer.icr.ac.uk/#/                                 |
# |High-quality chemical probes               |null                                                           |
# |Chemical Probes.org                        |http://new.chemicalprobes.org/                                 |
# |opnMe Portal                               |https://opnme.com/                                             |
# |Bromodomains chemical toolbox              |https://www.nature.com/articles/s41467-019-09672-2#article-info|
# |SGC Probes                                 |http://www.thesgc.org/chemical-probes                          |
# |Gray Laboratory Probes                     |http://graylab.dana-farber.org/probes.html#                    |
# |Protein methyltransferases chemical toolbox|https://www.nature.com/articles/s41467-018-07905-4             |
# |Nature Chemical Biology Probes             |http://www.nature.com/nchembio/chemical_probes.html            |
# |Open Science Probes                        |http://www.sgc-ffm.uni-frankfurt.de/#!start
# |Natural product-based probes and drugs     |https://pubs.rsc.org/en/content/articlelanding/2022/NP/D1NP00039J
# |JUMP-Target 1 Compound Set                 |https://jump-cellpainting.broadinstitute.org/                  |
# |JUMP-Target 2 Compound Set                 |https://jump-cellpainting.broadinstitute.org/                  |
# |Chemical Probes for Understudied Kinases   |https://pubs.acs.org/doi/10.1021/acs.jmedchem.1c00980          |
# ```

# %%
data.first()
# Out:
# Row(compound_id='30108', source='Bromodomains chemical toolbox', source_url='https://www.nature.com/articles/s41467-019-09672-2#article-info', probe_id='35251', origin='experimental', control="['D-Moses']", compound_name='L-Moses', inchiKey='MSFPLTWUFWOKBX-IFXJQAMLSA-N', basetarget_id='33454', target_name='Histone acetyltransferase KAT2B', target_symbols='KAT2B', target_id='130124', organism_id='2832', uniprot_ids='Q92831', uniprot_id='Q92831', score_id='7', percentage='50.0', probesDrugsScore='50.0', probeMinerScore=None, scoreInCells=None, scoreInOrganisms=None, actiontype_id=None, drugId=None)

# %%
(data
.filter(col('compound_id') == '888')
).show(10, False, True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 129963
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 1-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 129963
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 2-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 112344
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 3-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 112344
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 4-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 112345
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | inhibitor
#  drugId           | null
# -RECORD 5-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 112345
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | inhibitor
#  drugId           | null
# -RECORD 6-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 112346
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 7-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h
#  probe_id         | 39871
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 35770
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 112346
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null

# %%
data_m = (data
    # Drop columns that are not needed
    .drop('compound_id', 'basetarget_id', 'target_id', 'organism_id', 'score_id', 'percentage', 'uniprot_ids', 'probe_id')
    # Change Probe Miner source name
    .withColumn('source', when(col('source').contains('Probe Miner'), 'Probe Miner').otherwise(col('source')))
    # Build more complete URLs
    .withColumn(
    'source_url',
    when(col('source_url').contains('probeminer'), concat('source_url', 'uniprot_id'))
    .when(col('source_url').contains('probes.org'), concat(lit('https://new.chemicalprobes.org/?q='), 'compound_name'))
    .when(col('source_url').contains('thesgc'), concat('source_url', lit('/'), 'compound_name'))
    .when(col('source_url').contains('graylab'), lit(None))
    .when(col('source_url').contains('opnme'), concat(lit('https://opnme.com/search-results/'), 'compound_name'))
    .when(col('source_url').contains('frankfurt'),
          concat(
              element_at(split(col('source_url'), '#!start'), 1),
              lit('#!specificprobeoverview/'),
              'compound_name'))
    .otherwise(col('source_url')))
    # Create high-quality flag
    .withColumn('isHighQuality', when(col('source') == 'High-quality chemical probes', True).otherwise(False))
    # Clean rows where control = 1
    .withColumn('control', when(~col('control').contains(1), col('control')))
    .withColumn('control', when(~col('control').contains('2S'), col('control')))
    # Group data and collect sets
    .groupBy('uniprot_id', 'compound_name', 'drugId', 'inchiKey')
    .agg(
        collect_set(
            struct(
                col('source').alias('niceName'),
                col('source_url').alias('url'))
        ).alias('urls'),
        flatten(collect_set(array("control"))).alias('control'), # max size = 1
        collect_set("probesDrugsScore").alias('probesDrugsScore'),
        collect_set("probeMinerScore").alias('probeMinerScore'),
        collect_set("scoreInCells").alias('scoreInCells'),
        collect_set("scoreInOrganisms").alias('scoreInOrganisms'),
        flatten(collect_set(array("actiontype_id"))).alias('mechanismOfAction'),
        flatten(collect_set(array("isHighQuality"))).alias('isHighQuality'),
        collect_set("origin").alias("origin")
    )
    .withColumn('probesDrugsScore', array_max(col('probesDrugsScore')))
    .withColumn('probeMinerScore', array_max(col('probeMinerScore')))
    .withColumn('scoreInCells', array_max(col('scoreInCells')))
    .withColumn('scoreInOrganisms', array_max(col('scoreInOrganisms')))
    .withColumn('mechanismOfAction', expr('filter(mechanismOfAction, x -> x is not null)'))
    .withColumn('control', explode(col('control')))
    .withColumnRenamed('compound_name', 'id')
    .withColumnRenamed('uniprot_id', 'targetFromSourceId')
    .withColumn('urls', array_distinct(col('urls')))
    # Remove reference to High Quality Probes source as this is a subset curated by P&Ds
    # Problem: there are compounds only referenced with High Quality Probes 
    # Solution: remove it if there is already a reference, otherwise reference P&Ds 
    .withColumn('urls', 
        array_except(col('urls'), array(struct(lit('High-quality chemical probes').alias("niceName"),
        lit(None).cast("string").alias("url")))))
    .withColumn( 
        'urls',
        when(
            size(col('urls')) == 0,
            array(struct(
                lit('Probes & Drugs Portal').alias('niceName'),
                lit('https://www.probes-drugs.org').alias('url')))
        )
        .otherwise(col('urls'))
    )
    # Convert empty arrays into null
    .withColumn('mechanismOfAction', when(size(col('mechanismOfAction')) == 0, lit(None)).otherwise(col('mechanismOfAction')))
    .withColumn('origin', when(size(col('origin')) == 0, lit(None)).otherwise(col('origin')))
    # Transform isHighQuality to keep only True
    .withColumn('isHighQuality', when(array_contains(col('isHighQuality'), True), True).otherwise(False))
    .distinct()
)

data_m.count()
# Out:
# 4320

# %%
data_m.first()
# Out:
# Row(targetFromSourceId='B2RXH2', id='IOX1', drugId=None, inchiKey='JGRPKOGHYBAVMW-UHFFFAOYSA-N', urls=[Row(niceName='High-quality chemical probes', url='https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h'), Row(niceName='SGC Probes', url='http://www.thesgc.org/chemical-probes/IOX1')], control=None, probesDrugsScore='20.4', probeMinerScore='44.0', scoreInCells=None, scoreInOrganisms=None, mechanismOfAction=None, isHighQuality=True, origin=['experimental'])

# %%
data.withColumn('source_and_url', concat_ws('|', col('source'), col('source_url'))).first()
# Out:
# Row(compound_id='30108', source='Bromodomains chemical toolbox', source_url='https://www.nature.com/articles/s41467-019-09672-2#article-info', probe_id='35251', origin='experimental', control="['D-Moses']", compound_name='L-Moses', inchiKey='MSFPLTWUFWOKBX-IFXJQAMLSA-N', basetarget_id='33454', target_name='Histone acetyltransferase KAT2B', target_symbols='KAT2B', target_id='130124', organism_id='2832', uniprot_ids='Q92831', uniprot_id='Q92831', score_id='7', percentage='50.0', probesDrugsScore='50.0', probeMinerScore=None, scoreInCells=None, scoreInOrganisms=None, actiontype_id=None, drugId=None, source_and_url='Bromodomains chemical toolbox|https://www.nature.com/articles/s41467-019-09672-2#article-info')

# %%
test = (data
    # Drop columns that are not needed
    .drop('compound_id', 'basetarget_id', 'target_id', 'organism_id', 'score_id', 'percentage', 'uniprot_ids', 'probe_id')
    # Change Probe Miner source name
    .withColumn('source', when(col('source').contains('Probe Miner'), 'Probe Miner').otherwise(col('source')))
    # Build more complete URLs
    .withColumn(
    'source_url',
    when(col('source_url').contains('probeminer'), concat('source_url', 'uniprot_id'))
    .when(col('source_url').contains('probes.org'), concat(lit('https://new.chemicalprobes.org/?q='), 'compound_name'))
    .when(col('source_url').contains('thesgc'), concat('source_url', lit('/'), 'compound_name'))
    .when(col('source_url').contains('graylab'), lit(None))
    .when(col('source_url').contains('opnme'), concat(lit('https://opnme.com/search-results/'), 'compound_name'))
    .when(col('source_url').contains('frankfurt'),
          concat(
              element_at(split(col('source_url'), '#!start'), 1),
              lit('#!specificprobeoverview/'),
              'compound_name'))
    .otherwise(col('source_url')))
    # Create high-quality flag and set source to null if it is High Quality Probes
    .withColumn('isHighQuality', when(col('source') == 'High-quality chemical probes', True).otherwise(False))
    .withColumn('source', when(col('source').contains('High-quality chemical probes'), lit(None)).otherwise(col('source')))
    # Zip source and url in the same string not to lose their correspondence
    .withColumn('source_and_url', concat_ws('|', col('source'), col('source_url')))
    # Clean rows where control = 1
    .withColumn('control', when(~col('control').contains(1), col('control')))
    .withColumn('control', when(~col('control').contains('2S'), col('control')))
    # Group data and collect sets
    .groupBy('uniprot_id', 'compound_name', 'drugId', 'inchiKey')
    .agg(
        collect_set(col('source_and_url')).alias('urls'),
        flatten(collect_set(array("control"))).alias('control'), # max size = 1
        collect_set("probesDrugsScore").alias('probesDrugsScore'),
        collect_set("probeMinerScore").alias('probeMinerScore'),
        collect_set("scoreInCells").alias('scoreInCells'),
        collect_set("scoreInOrganisms").alias('scoreInOrganisms'),
        flatten(collect_set(array("actiontype_id"))).alias('mechanismOfAction'),
        flatten(collect_set(array("isHighQuality"))).alias('isHighQuality'),
        collect_set("origin").alias("origin")
    )
    .withColumn('probesDrugsScore', array_max(col('probesDrugsScore')))
    .withColumn('probeMinerScore', array_max(col('probeMinerScore')))
    .withColumn('scoreInCells', array_max(col('scoreInCells')))
    .withColumn('scoreInOrganisms', array_max(col('scoreInOrganisms')))
    .withColumn('mechanismOfAction', expr('filter(mechanismOfAction, x -> x is not null)'))
    .withColumn('control', explode(col('control')))
    .withColumnRenamed('compound_name', 'id')
    .withColumnRenamed('uniprot_id', 'targetFromSourceId')
    # Remove reference to High Quality Probes source as this is a subset curated by P&Ds
    # Problem: there are compounds only referenced with High Quality Probes 
    # Solution: remove it if there is already a reference, otherwise reference P&Ds 
    # Convert empty arrays into null
    .withColumn('mechanismOfAction', when(size(col('mechanismOfAction')) == 0, lit(None)).otherwise(col('mechanismOfAction')))
    .withColumn('origin', when(size(col('origin')) == 0, lit(None)).otherwise(col('origin')))
    # Transform isHighQuality to keep only True
    .withColumn('isHighQuality', when(array_contains(col('isHighQuality'), True), True).otherwise(False))
    .distinct()
)

test.show(truncate=False)
# Out:
# +------------------+---------+------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+-------+----------------+---------------+------------+----------------+-----------------+-------------+--------------+
# |targetFromSourceId|id       |drugId|inchiKey                   |urls                                                                                                                      |control|probesDrugsScore|probeMinerScore|scoreInCells|scoreInOrganisms|mechanismOfAction|isHighQuality|origin        |
# +------------------+---------+------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+-------+----------------+---------------+------------+----------------+-----------------+-------------+--------------+
# |B2RXH2            |IOX1     |null  |JGRPKOGHYBAVMW-UHFFFAOYSA-N|[SGC Probes|http://www.thesgc.org/chemical-probes/IOX1, https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h]|null   |20.4            |44.0           |null        |null            |null             |true         |[experimental]|
# |O00141            |SGK1-IN-1|null  |DDKHTWASHUKHLD-UHFFFAOYSA-N|[https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h]                                                       |null   |80.0            |62.0           |null        |null            |[inhibitor]      |true         |[calculated]  |
# |O00255            |M-808    |null  |BTSUNSRQYLVGIS-ADTYUTHVSA-N|[Chemical Probes.org|https://new.chemicalprobes.org/?q=M-808]                                                             |null   |40.0            |null           |57.5        |50.0            |null             |false        |[experimental]|
# |O00255            |MI-2     |null  |SRQYLNYQAPCPIR-UHFFFAOYSA-N|[Nature Chemical Biology Probes|http://www.nature.com/nchembio/chemical_probes.html]                                      |null   |20.0            |31.0           |null        |null            |null             |false        |[experimental]|
# |O00257            |UNC3866  |null  |UMRRDXVUROEIKJ-JCXBGQGISA-N|[Chemical Probes.org|https://new.chemicalprobes.org/?q=UNC3866]                                                           |null   |30.0            |67.0           |62.5        |0.0             |null             |false        |[experimental]|
# |O00311            |PD070157 |null  |IYFKRIWGRGFLBL-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |49.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070158 |null  |NYNANQKQYVAHFV-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070159 |null  |WPDINEQTRUOZHZ-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070160 |null  |GSCKZFSBVHCSKZ-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070162 |null  |AMSJYRQZMOVVGU-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070166 |null  |RPPQQNWPUSILFF-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070167 |null  |GQGDIBZCZVAYNM-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070173 |null  |VCHRCLNIIWLDLA-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |50.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070174 |null  |ZFUUZACDRUZMSC-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |50.0            |56.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070175 |null  |QTMSXNQGBZJNRQ-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |51.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070176 |null  |KMOZGTUUYJFWQK-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |50.0            |57.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070178 |null  |GIEWZQNAONSKKX-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |50.0            |57.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070180 |null  |AQGTUBOJXORWCG-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |51.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070181 |null  |PSNUHTHUWXIRLT-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |50.0            |57.0           |null        |null            |null             |false        |[calculated]  |
# |O00311            |PD070182 |null  |JAKVUTLQQQVGSN-UHFFFAOYSA-N|[Probe Miner|http://probeminer.icr.ac.uk/#/O00311]                                                                        |null   |40.0            |52.0           |null        |null            |null             |false        |[calculated]  |
# +------------------+---------+------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+-------+----------------+---------------+------------+----------------+-----------------+-------------+--------------+
# only showing top 20 rows

# %%
test.filter(size(col('urls')) > 1).first()
# Out:
# Row(targetFromSourceId='B2RXH2', id='IOX1', drugId=None, inchiKey='JGRPKOGHYBAVMW-UHFFFAOYSA-N', urls=['SGC Probes|http://www.thesgc.org/chemical-probes/IOX1', 'https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h'], control=None, probesDrugsScore='20.4', probeMinerScore='44.0', scoreInCells=None, scoreInOrganisms=None, mechanismOfAction=None, isHighQuality=True, origin=['experimental'])

# %%
data_m.show(10, False, True)
# Out:
# [Stage 17:==============>                                           (1 + 3) / 4]
# -RECORD 0---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | B2RXH2
#  id                 | IOX1
#  drugId             | null
#  inchiKey           | JGRPKOGHYBAVMW-UHFFFAOYSA-N
#  urls               | [{High-quality chemical probes, https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h}, {SGC Probes, http://www.thesgc.org/chemical-probes/IOX1}]
#  control            | null
#  probesDrugsScore   | 20.4
#  probeMinerScore    | 44.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | true
#  origin             | [experimental]
# -RECORD 1---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00141
#  id                 | SGK1-IN-1
#  drugId             | null
#  inchiKey           | DDKHTWASHUKHLD-UHFFFAOYSA-N
#  urls               | [{High-quality chemical probes, https://pubs.rsc.org/en/content/articlelanding/2021/md/d1md00138h}]
#  control            | null
#  probesDrugsScore   | 80.0
#  probeMinerScore    | 62.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | [inhibitor]
#  isHighQuality      | true
#  origin             | [calculated]
# -RECORD 2---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00255
#  id                 | MI-2
#  drugId             | null
#  inchiKey           | SRQYLNYQAPCPIR-UHFFFAOYSA-N
#  urls               | [{Nature Chemical Biology Probes, http://www.nature.com/nchembio/chemical_probes.html}]
#  control            | null
#  probesDrugsScore   | 20.0
#  probeMinerScore    | 31.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [experimental]
# -RECORD 3---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070157
#  drugId             | null
#  inchiKey           | IYFKRIWGRGFLBL-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 49.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 4---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070158
#  drugId             | null
#  inchiKey           | NYNANQKQYVAHFV-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 5---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070159
#  drugId             | null
#  inchiKey           | WPDINEQTRUOZHZ-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 6---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070160
#  drugId             | null
#  inchiKey           | GSCKZFSBVHCSKZ-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 7---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070162
#  drugId             | null
#  inchiKey           | AMSJYRQZMOVVGU-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 8---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070166
#  drugId             | null
#  inchiKey           | RPPQQNWPUSILFF-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 9---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070167
#  drugId             | null
#  inchiKey           | GQGDIBZCZVAYNM-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# only showing top 10 rows

# %%
data_m.withColumn('s', explode('urls')).groupBy('s.niceName').count().toPandas()
# Out:
#                                        niceName  count
# 0                  High-quality chemical probes    940
# 1                           Open Science Probes    130
# 2                    JUMP-Target 2 Compound Set     72
# 3                                   Probe Miner   3255
# 4                           Chemical Probes.org    748
# 5                                  opnMe Portal     87
# 6      Chemical Probes for Understudied Kinases     41
# 7                 Bromodomains chemical toolbox     55
# 8                        Gray Laboratory Probes    134
# 9   Protein methyltransferases chemical toolbox     28
# 10               Nature Chemical Biology Probes     51
# 11                   JUMP-Target 1 Compound Set     72
# 12       Natural product-based probes and drugs     19
# 13                                   SGC Probes    170

# %%
data_m.coalesce(1).write.json(f'output/{version}/chemicalprobes_{version}', mode='overwrite')
