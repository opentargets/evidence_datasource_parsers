# %%
import pandas as pd

# %%
version = '4'

# %% [markdown]
# ## 1. Extract all compound IDs that belong to a Chemical Probes Set
#
# Compound sets per data source:
# ```
# Bromodomains chemical toolbox, 277
# Chemical Probes.org, 15
# Gray Laboratory Probes, 240
# MLP probes, 14 --> Legacy compound set
# Open Science Probes, 213
# High-quality chemical probes, 395 --> Turn into a boolean label
# Nature Chemical Biology Probes, 19 --> Legacy compound set
# opnMe Portal, 219
# Probe Miner (suitable probes), 227
# Protein methyltransferases chemical toolbox, 278
# SGC Probes, 28
# Tool Compound Set, 19`
# ```

# %%
compound2compoundset = pd.read_csv(f"csv_dumps/{version}/compoundtocompoundset.csv", sep=",", header=0, usecols=['compound_id', 'compoundset_id'])
compoundsets = (
    pd.read_csv(
        "csv_dumps/3/compoundset.csv",
        sep=",",
        header=0,
        usecols=['compoundsetid', 'name', 'source_url'])
    .rename(columns={'name' : 'source'})
)

# %%
probes_compoundsetids = [277, 15, 240, 213, 395, 219, 227, 278, 28, 19]

compound2compoundset = (
    compound2compoundset.merge(
        compoundsets[['compoundsetid', 'source', 'source_url']],
        left_on='compoundset_id',
        right_on='compoundsetid',
        how='inner'
    )
    # Select compounds coming from Probes data sources
    .query('compoundset_id in @probes_compoundsetids')
    .drop(['compoundsetid', 'compoundset_id'], axis=1)
)

print(compound2compoundset.shape[0])
compound2compoundset.head()
# Out:
# 4604
#        compound_id               source  \
# 25331       123778  Open Science Probes
# 25332       123780  Open Science Probes
# 25333        28070  Open Science Probes
# 25334        54747  Open Science Probes
# 25335        29563  Open Science Probes
#
#                                         source_url
# 25331  http://www.sgc-ffm.uni-frankfurt.de/#!start
# 25332  http://www.sgc-ffm.uni-frankfurt.de/#!start
# 25333  http://www.sgc-ffm.uni-frankfurt.de/#!start
# 25334  http://www.sgc-ffm.uni-frankfurt.de/#!start
# 25335  http://www.sgc-ffm.uni-frankfurt.de/#!start

# %% [markdown]
# # 🧐 Question: If probe in different sources, do we duplicate or want the id to be unique? Unique ID

# %% [markdown]
# ## 2.1 Pair compound IDs with probes IDs

# %%
probes = (
    pd.read_csv(
        "csv_dumps/3/probe.csv",
        sep=",",
        header=0,
        usecols=['probeid', 'compound_id', 'control', 'origin_id'],
        dtype={'probeid':'int64', 'control':'category'})
    .rename(columns={'probeid':'probe_id', 'origin_id':'origin'})
)
probes.head(5)
# Out:
#    probe_id  compound_id      origin control
# 0     28998        35591  calculated     NaN
# 1     29013        28478  calculated     NaN
# 2     26700        45619  calculated     NaN
# 3     27263        45951  calculated     NaN
# 4     28219        46613  calculated     NaN

# %%
probes.control.value_counts()
# Out:
# 1              1048
# BI-6354           7
# FM-743            7
# BI-5273           6
# (-)-JQ1           5
#                ...
# MRL-SYKi-NC       1
# PPTN-NC           1
# BI-55CL           1
# MRL-CB1-NC        1
# PF-00911705       1
# Name: control, Length: 126, dtype: int64

# %%
'''
# Controls are read as strings
def str_to_list(X):
    if isinstance(X, str):
        arr = X.strip('[]').split(',')
        arr = [e.strip("''") for e in arr]
        return arr
    return None
    
    
probes['control'] = probes['control'].apply(lambda X: str_to_list(X))

probes = probes.explode('control')
'''
# Out:
# '\n# Controls are read as strings\ndef str_to_list(X):\n    if isinstance(X, str):\n        arr = X.strip(\'[]\').split(\',\')\n        arr = [e.strip("\'\'") for e in arr]\n        return arr\n    return None\n    \n    \nprobes[\'control\'] = probes[\'control\'].apply(lambda X: str_to_list(X))\n\nprobes = probes.explode(\'control\')\n'

# %%
# There are 13 compounds not present in the probes dataset
# All coming from 'High-quality chemical probes'

df = compound2compoundset.merge(
    probes,
    on='compound_id',
    how='left'
)

df.head(5)
# Out:
#    compound_id               source  \
# 0       123778  Open Science Probes
# 1       123780  Open Science Probes
# 2        28070  Open Science Probes
# 3        54747  Open Science Probes
# 4        29563  Open Science Probes
#
#                                     source_url  probe_id        origin  \
# 0  http://www.sgc-ffm.uni-frankfurt.de/#!start       NaN           NaN
# 1  http://www.sgc-ffm.uni-frankfurt.de/#!start       NaN           NaN
# 2  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 3  http://www.sgc-ffm.uni-frankfurt.de/#!start   25390.0  experimental
# 4  http://www.sgc-ffm.uni-frankfurt.de/#!start   24050.0  experimental
#
#      control
# 0        NaN
# 1        NaN
# 2    PPTN-NC
# 3    BAY-786
# 4  A-1107969

# %% [markdown]
# ## 2.2 Extract compound name and inchikey

# %%
compounds = (
    pd.read_csv(
        "csv_dumps/3/compound.csv",
        sep=",",
        header=0,
        usecols=['compoundid', 'name', 'inchikey'])
    .rename(columns={'compoundid':'compound_id', 'name':'compound_name', 'inchikey':'inchiKey'})
)

# %%
df = df.merge(
    compounds,
    on='compound_id',
    how='left'
)

df.head(5)
# Out:
#    compound_id               source  \
# 0       123778  Open Science Probes
# 1       123780  Open Science Probes
# 2        28070  Open Science Probes
# 3        54747  Open Science Probes
# 4        29563  Open Science Probes
#
#                                     source_url  probe_id        origin  \
# 0  http://www.sgc-ffm.uni-frankfurt.de/#!start       NaN           NaN
# 1  http://www.sgc-ffm.uni-frankfurt.de/#!start       NaN           NaN
# 2  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 3  http://www.sgc-ffm.uni-frankfurt.de/#!start   25390.0  experimental
# 4  http://www.sgc-ffm.uni-frankfurt.de/#!start   24050.0  experimental
#
#      control compound_name                     inchiKey
# 0        NaN           NaN                          NaN
# 1        NaN           NaN                          NaN
# 2    PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N
# 3    BAY-786       BAY-784  PZGSYNNVPNLHQG-SANMLTNESA-N
# 4  A-1107969     A-1155463  SOYCFODXNRVBTI-UHFFFAOYSA-N

# %% [markdown]
# ## 3. Extract target associated with probe

# %%
# First extract target_id
probes2targets = pd.read_csv("csv_dumps/3/probetobasetarget.csv",
                             sep=",",
                             header=0,
                             usecols=['probe_id', 'basetarget_id'])
                             

df = df.merge(
    probes2targets,
    on='probe_id',
    how='left'
)

# %% [markdown]
# Count of probes without an associated target per datasource:
# ```
# MLP Probes                                     114
# High-quality chemical probes                    44
# Nature Chemical Biology Probes                  39
# Chemical Probes.org                             25
# Protein methyltransferases chemical toolbox     20
# SGC Probes                                      20
# Open Science Probes                              3
# Gray Laboratory Probes                           2
# opnMe Portal                                     1
# Probe Miner (suitable probes)                    1
# ```

# %%
# Then extract target name

base_targets = (
    pd.read_csv(
        "csv_dumps/3/basetarget.csv",
        sep=",",
        header=0,
        usecols=['basetargetid', 'name', 'gene_name'])
    .rename(columns={'basetargetid':'basetarget_id', 'name':'target_name', 'gene_name':'target_symbols'})
)

# %%
df = df.merge(
    base_targets,
    on='basetarget_id',
    how='left'
)

df.head(10)
# Out:
#    compound_id               source  \
# 0       123778  Open Science Probes
# 1       123780  Open Science Probes
# 2        28070  Open Science Probes
# 3        54747  Open Science Probes
# 4        29563  Open Science Probes
# 5        29563  Open Science Probes
# 6        29563  Open Science Probes
# 7        18237  Open Science Probes
# 8        42890  Open Science Probes
# 9        42876  Open Science Probes
#
#                                     source_url  probe_id        origin  \
# 0  http://www.sgc-ffm.uni-frankfurt.de/#!start       NaN           NaN
# 1  http://www.sgc-ffm.uni-frankfurt.de/#!start       NaN           NaN
# 2  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 3  http://www.sgc-ffm.uni-frankfurt.de/#!start   25390.0  experimental
# 4  http://www.sgc-ffm.uni-frankfurt.de/#!start   24050.0  experimental
# 5  http://www.sgc-ffm.uni-frankfurt.de/#!start   24619.0  experimental
# 6  http://www.sgc-ffm.uni-frankfurt.de/#!start   25368.0  experimental
# 7  http://www.sgc-ffm.uni-frankfurt.de/#!start   25423.0  experimental
# 8  http://www.sgc-ffm.uni-frankfurt.de/#!start   25432.0  experimental
# 9  http://www.sgc-ffm.uni-frankfurt.de/#!start   25365.0  experimental
#
#        control compound_name                     inchiKey  basetarget_id  \
# 0          NaN           NaN                          NaN            NaN
# 1          NaN           NaN                          NaN            NaN
# 2      PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 3      BAY-786       BAY-784  PZGSYNNVPNLHQG-SANMLTNESA-N        24051.0
# 4    A-1107969     A-1155463  SOYCFODXNRVBTI-UHFFFAOYSA-N        23460.0
# 5    A-1107969     A-1155463  SOYCFODXNRVBTI-UHFFFAOYSA-N        23460.0
# 6    A-1107969     A-1155463  SOYCFODXNRVBTI-UHFFFAOYSA-N        23460.0
# 7  PF-05257137   PF-05105679  BXNMZRPTQFVRFA-QGZVFWFLSA-N        23884.0
# 8  MRL-SYKi-NC      MRL-SYKi  OYKPWSZSBLRRPL-HOYKHHGWSA-N        22739.0
# 9      BAY-827       BAY-474  QKVFMAAIXZONRN-UHFFFAOYSA-N        22922.0
#
#                                          target_name target_symbols
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                P2Y purinoceptor 14         P2RY14
# 3            Gonadotropin-releasing hormone receptor          GNRHR
# 4                               Bcl-2-like protein 1         BCL2L1
# 5                               Bcl-2-like protein 1         BCL2L1
# 6                               Bcl-2-like protein 1         BCL2L1
# 7  Transient receptor potential cation channel su...          TRPM8
# 8                        Tyrosine-protein kinase SYK            SYK
# 9                  Hepatocyte growth factor receptor            MET

# %%
# Extract uniprot ID from target

basetarget2target = (
    pd.read_csv(
        "csv_dumps/3/targettobasetarget.csv",
        sep=",",
        header=0,
        usecols=['basetarget_id', 'target_id']))

targets = (
    pd.read_csv(
        "csv_dumps/3/target.csv",
        sep=",",
        header=0,
        usecols=['targetid', 'organism_id', 'uniprotid'])
    .rename(columns={'targetid': 'target_id', 'uniprotid':'uniprot_ids'})
)

# %%
df = (
    # Map from basetarget to target
    df.merge(
        basetarget2target,
        on='basetarget_id',
        how='left'
    )
    # Extract organism_id and uniprot_ids from target
    .merge(
        targets,
        on='target_id',
        how='left'
    )
    # Select human as organism (organism_id = [5428, 2832])
    .query('organism_id in [5428, 2832]')
)

# %%
# Split and explode the uniprot_ids columns

df['uniprot_id'] = df['uniprot_ids'].apply(lambda X: X.split(','))
df = df.explode('uniprot_id')

# %%
df.head()
# Out:
#     compound_id               source  \
# 2         28070  Open Science Probes
# 9         28070  Open Science Probes
# 10        28070  Open Science Probes
# 11        28070  Open Science Probes
# 12        54747  Open Science Probes
#
#                                      source_url  probe_id        origin  \
# 2   http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 9   http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 10  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 11  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 12  http://www.sgc-ffm.uni-frankfurt.de/#!start   25390.0  experimental
#
#     control compound_name                     inchiKey  basetarget_id  \
# 2   PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 9   PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 10  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 11  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 12  BAY-786       BAY-784  PZGSYNNVPNLHQG-SANMLTNESA-N        24051.0
#
#                                 target_name target_symbols  target_id  \
# 2                       P2Y purinoceptor 14         P2RY14   100675.0
# 9                       P2Y purinoceptor 14         P2RY14    94426.0
# 10                      P2Y purinoceptor 14         P2RY14    94427.0
# 11                      P2Y purinoceptor 14         P2RY14    94428.0
# 12  Gonadotropin-releasing hormone receptor          GNRHR   100562.0
#
#     organism_id uniprot_ids uniprot_id
# 2        2832.0      Q15391     Q15391
# 9        2832.0      Q15391     Q15391
# 10       2832.0      Q15391     Q15391
# 11       2832.0      Q15391     Q15391
# 12       2832.0      P30968     P30968

# %% [markdown]
# ## 4. Extract scores

# %%
scores = (
    pd.read_csv(
        "csv_dumps/3/compoundtargetscore.csv",
        sep=",",
        header=0,
        usecols=['compound_id', 'basetarget_id', 'percentage', 'score_id'])
    # Filter with only score_ids of interest
    .query('score_id in [1, 5, 6, 7]')
)

df_s = df.merge(
        scores,
        on=['basetarget_id', 'compound_id'],
        how='left'
)

# %%
df_s
# Out:
#        compound_id               source  \
# 0            28070  Open Science Probes
# 1            28070  Open Science Probes
# 2            28070  Open Science Probes
# 3            28070  Open Science Probes
# 4            28070  Open Science Probes
# ...            ...                  ...
# 99188        97062           SGC Probes
# 99189        97062           SGC Probes
# 99190        97062           SGC Probes
# 99191        97062           SGC Probes
# 99192        97062           SGC Probes
#
#                                         source_url  probe_id        origin  \
# 0      http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 1      http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 2      http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 3      http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 4      http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# ...                                            ...       ...           ...
# 99188        http://www.thesgc.org/chemical-probes   28797.0  experimental
# 99189        http://www.thesgc.org/chemical-probes   28797.0  experimental
# 99190        http://www.thesgc.org/chemical-probes   28797.0  experimental
# 99191        http://www.thesgc.org/chemical-probes   28797.0  experimental
# 99192        http://www.thesgc.org/chemical-probes   28797.0  experimental
#
#        control compound_name                     inchiKey  basetarget_id  \
# 0      PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 1      PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 2      PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 3      PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 4      PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# ...        ...           ...                          ...            ...
# 99188      NaN    NVS-MLLT-1  ZRTFTZCKJUNZIU-HNNXBMFYSA-N        26864.0
# 99189      NaN    NVS-MLLT-1  ZRTFTZCKJUNZIU-HNNXBMFYSA-N        26864.0
# 99190      NaN    NVS-MLLT-1  ZRTFTZCKJUNZIU-HNNXBMFYSA-N        26864.0
# 99191      NaN    NVS-MLLT-1  ZRTFTZCKJUNZIU-HNNXBMFYSA-N        26864.0
# 99192      NaN    NVS-MLLT-1  ZRTFTZCKJUNZIU-HNNXBMFYSA-N        26864.0
#
#                target_name target_symbols  target_id  organism_id uniprot_ids  \
# 0      P2Y purinoceptor 14         P2RY14   100675.0       2832.0      Q15391
# 1      P2Y purinoceptor 14         P2RY14   100675.0       2832.0      Q15391
# 2      P2Y purinoceptor 14         P2RY14    94426.0       2832.0      Q15391
# 3      P2Y purinoceptor 14         P2RY14    94426.0       2832.0      Q15391
# 4      P2Y purinoceptor 14         P2RY14    94427.0       2832.0      Q15391
# ...                    ...            ...        ...          ...         ...
# 99188         Protein AF-9          MLLT3    84336.0       2832.0      P42568
# 99189         Protein AF-9          MLLT3    84336.0       2832.0      P42568
# 99190         Protein AF-9          MLLT3    84337.0       2832.0      P42568
# 99191         Protein AF-9          MLLT3    84337.0       2832.0      P42568
# 99192         Protein AF-9          MLLT3    84337.0       2832.0      P42568
#
#       uniprot_id  score_id  percentage
# 0         Q15391       1.0        26.0
# 1         Q15391       7.0        90.0
# 2         Q15391       1.0        26.0
# 3         Q15391       7.0        90.0
# 4         Q15391       1.0        26.0
# ...          ...       ...         ...
# 99188     P42568       6.0         0.0
# 99189     P42568       7.0        20.0
# 99190     P42568       5.0        87.5
# 99191     P42568       6.0         0.0
# 99192     P42568       7.0        20.0
#
# [99193 rows x 17 columns]

# %%
df_s["probesDrugsScore"] = df_s.apply(lambda X: X.percentage if X.score_id == 7 else None, axis=1)
df_s['probeMinerScore'] = df_s.apply(lambda X: X.percentage if X.score_id == 1 else None, axis=1)
df_s['scoreInCells'] = df_s.apply(lambda X: X.percentage if X.score_id == 5 else None, axis=1)
df_s['scoreInOrganisms'] = df_s.apply(lambda X: X.percentage if X.score_id == 6 else None, axis=1)

# %%
# Right now I have duplicated rows due to:
# several data sources evidencing the same assoc +
# exploded uniprot ids +
# I have to coalesce the score rows

# %%
df = df_s.copy()

# %% [markdown]
# ## 5. Extract MoA

# %%
moas = (
    pd.read_csv(
        "csv_dumps/3/compoundaction.csv",
        sep=",",
        header=0,
        usecols=['compound_id', 'target_id', 'actiontype_id'])
)

# %%
df = df.merge(
        moas,
        on=['target_id', 'compound_id'],
        how='left'
)

# %%
df.head()
# Out:
#    compound_id               source  \
# 0        28070  Open Science Probes
# 1        28070  Open Science Probes
# 2        28070  Open Science Probes
# 3        28070  Open Science Probes
# 4        28070  Open Science Probes
#
#                                     source_url  probe_id        origin  \
# 0  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 1  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 2  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 3  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 4  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
#
#    control compound_name                     inchiKey  basetarget_id  \
# 0  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 1  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 2  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 3  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 4  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
#
#            target_name  ... organism_id  uniprot_ids  uniprot_id score_id  \
# 0  P2Y purinoceptor 14  ...      2832.0       Q15391      Q15391      1.0
# 1  P2Y purinoceptor 14  ...      2832.0       Q15391      Q15391      7.0
# 2  P2Y purinoceptor 14  ...      2832.0       Q15391      Q15391      1.0
# 3  P2Y purinoceptor 14  ...      2832.0       Q15391      Q15391      7.0
# 4  P2Y purinoceptor 14  ...      2832.0       Q15391      Q15391      1.0
#
#   percentage  probesDrugsScore  probeMinerScore  scoreInCells  \
# 0       26.0               NaN             26.0           NaN
# 1       90.0              90.0              NaN           NaN
# 2       26.0               NaN             26.0           NaN
# 3       90.0              90.0              NaN           NaN
# 4       26.0               NaN             26.0           NaN
#
#    scoreInOrganisms  actiontype_id
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN     antagonist
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 6. Map to drugId

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = (SparkSession.builder
    .appName('spark')
    .getOrCreate())

# %%
drug_idx = (
    spark.read.parquet('/Users/irene/Documents/dev/pyspark/21.11.1/molecule')
    .select(col('id').alias('drugId'), 'inchiKey')
    .toPandas()
)

# %%
df = (
    # Get drugId
    df.merge(
        drug_idx,
        on='inchiKey',
        how='left')
)


df.head()
# Out:
#    compound_id               source  \
# 0        28070  Open Science Probes
# 1        28070  Open Science Probes
# 2        28070  Open Science Probes
# 3        28070  Open Science Probes
# 4        28070  Open Science Probes
#
#                                     source_url  probe_id        origin  \
# 0  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 1  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 2  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 3  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
# 4  http://www.sgc-ffm.uni-frankfurt.de/#!start   25444.0  experimental
#
#    control compound_name                     inchiKey  basetarget_id  \
# 0  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 1  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 2  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 3  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
# 4  PPTN-NC          PPTN  FOECKIWHCOYYFL-UHFFFAOYSA-N        21847.0
#
#            target_name  ... uniprot_ids  uniprot_id  score_id percentage  \
# 0  P2Y purinoceptor 14  ...      Q15391      Q15391       1.0       26.0
# 1  P2Y purinoceptor 14  ...      Q15391      Q15391       7.0       90.0
# 2  P2Y purinoceptor 14  ...      Q15391      Q15391       1.0       26.0
# 3  P2Y purinoceptor 14  ...      Q15391      Q15391       7.0       90.0
# 4  P2Y purinoceptor 14  ...      Q15391      Q15391       1.0       26.0
#
#   probesDrugsScore  probeMinerScore  scoreInCells  scoreInOrganisms  \
# 0              NaN             26.0           NaN               NaN
# 1             90.0              NaN           NaN               NaN
# 2              NaN             26.0           NaN               NaN
# 3             90.0              NaN           NaN               NaN
# 4              NaN             26.0           NaN               NaN
#
#    actiontype_id  drugId
# 0            NaN     NaN
# 1            NaN     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4     antagonist     NaN
#
# [5 rows x 23 columns]

# %%
df = df.astype({
    'probe_id': 'Int64',
    'basetarget_id': 'Int64',
    'target_id': 'Int64',
    'organism_id': 'Int64',
    'score_id': 'Int64'
})

# %%
df.to_csv(f'output/{version}/chemprobes_v{version}_1.tsv', sep='\t', header=True, index=False)

# %%
df.iloc[0]
# Out:
# compound_id                                               28070
# source                                      Open Science Probes
# source_url          http://www.sgc-ffm.uni-frankfurt.de/#!start
# probe_id                                                  25444
# origin                                             experimental
# control                                                 PPTN-NC
# compound_name                                              PPTN
# inchiKey                            FOECKIWHCOYYFL-UHFFFAOYSA-N
# basetarget_id                                             21847
# target_name                                 P2Y purinoceptor 14
# target_symbols                                           P2RY14
# target_id                                                100675
# organism_id                                                2832
# uniprot_ids                                              Q15391
# uniprot_id                                               Q15391
# score_id                                                      1
# percentage                                                 26.0
# probesDrugsScore                                            NaN
# probeMinerScore                                            26.0
# scoreInCells                                                NaN
# scoreInOrganisms                                            NaN
# actiontype_id                                               NaN
# drugId                                                      NaN
# Name: 0, dtype: object

# %% [markdown]
# ## 7. Build final dataset

# %%
data = spark.read.csv(f'output/{version}/chemprobes_v{version}_1.tsv', sep='\t', header=True)

# %% [markdown]
# All posible URLs
# ```
# +-------------------------------------------+---------------------------------------------------------------+
# |source                                     |source_url                                                     |
# +-------------------------------------------+---------------------------------------------------------------+
# |Probe Miner (suitable probes)              |http://probeminer.icr.ac.uk/#/                                 |
# |High-quality chemical probes               |null                                                           |
# |Chemical Probes.org                        |http://www.chemicalprobes.org/                                 |
# |opnMe Portal                               |https://opnme.com/                                             |
# |Bromodomains chemical toolbox              |https://www.nature.com/articles/s41467-019-09672-2#article-info|
# |SGC Probes                                 |http://www.thesgc.org/chemical-probes                          |
# |Gray Laboratory Probes                     |http://graylab.dana-farber.org/probes.html#                    |
# |Protein methyltransferases chemical toolbox|https://www.nature.com/articles/s41467-018-07905-4             |
# |Nature Chemical Biology Probes             |http://www.nature.com/nchembio/chemical_probes.html            |
# |Open Science Probes                        |http://www.sgc-ffm.uni-frankfurt.de/#!start `
#
# ```

# %%
data.first()
# Out:
# Row(compound_id='30108', source='Bromodomains chemical toolbox', source_url='https://www.nature.com/articles/s41467-019-09672-2#article-info', probe_id='24043', origin='experimental', control='D-Moses', compound_name='L-Moses', inchiKey='MSFPLTWUFWOKBX-IFXJQAMLSA-N', basetarget_id='22470', target_name='Histone acetyltransferase KAT2B', target_symbols='KAT2B', target_id='100905', organism_id='2832', uniprot_ids='Q92831', uniprot_id='Q92831', score_id='7', percentage='50.0', probesDrugsScore='50.0', probeMinerScore=None, scoreInCells=None, scoreInOrganisms=None, actiontype_id=None, drugId=None)

# %%
(data
.filter(col('compound_id') == '888')
).show(10, False, True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 100742
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 1-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 100742
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 2-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79436
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 3-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79436
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 4-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79437
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 5-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79437
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 6-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79438
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | inhibitor
#  drugId           | null
# -RECORD 7-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79438
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | inhibitor
#  drugId           | null
# -RECORD 8-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79439
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 1
#  percentage       | 46.0
#  probesDrugsScore | null
#  probeMinerScore  | 46.0
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null
# -RECORD 9-----------------------------------------------------------------------------------------
#  compound_id      | 888
#  source           | High-quality chemical probes
#  source_url       | null
#  probe_id         | 28923
#  origin           | calculated
#  control          | null
#  compound_name    | TGX-221
#  inchiKey         | CPRAGQJXBLMUEL-UHFFFAOYSA-N
#  basetarget_id    | 25012
#  target_name      | Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform
#  target_symbols   | PIK3CB
#  target_id        | 79439
#  organism_id      | 2832
#  uniprot_ids      | P42338
#  uniprot_id       | P42338
#  score_id         | 7
#  percentage       | 86.3
#  probesDrugsScore | 86.3
#  probeMinerScore  | null
#  scoreInCells     | null
#  scoreInOrganisms | null
#  actiontype_id    | null
#  drugId           | null

# %%
data_m = (data
    # Drop columns that are not needed
    .drop('compound_id', 'basetarget_id', 'target_id', 'organism_id', 'score_id', 'percentage', 'uniprot_ids', 'probe_id')
    # Change Probe Miner source name
    .withColumn('source', when(col('source').contains('Probe Miner'), 'Probe Miner').otherwise(col('source')))
    # Build more complete URLs
    .withColumn(
    'source_url',
    when(col('source_url').contains('probeminer'), concat('source_url', 'uniprot_id'))
    .when(col('source_url').contains('probes.org'), concat(lit('https://new.chemicalprobes.org/?q='), 'compound_name'))
    .when(col('source_url').contains('thesgc'), concat('source_url', lit('/'), 'compound_name'))
    .when(col('source_url').contains('graylab'), lit(None))
    .when(col('source_url').contains('opnme'), concat(lit('https://opnme.com/search-results/'), 'compound_name'))
    .when(col('source_url').contains('frankfurt'),
          concat(
              element_at(split(col('source_url'), '#!start'), 1),
              lit('#!specificprobeoverview/'),
              'compound_name'))
    .otherwise(col('source_url')))
    # Create high-quality flag
    .withColumn('isHighQuality', when(col('source') == 'High-quality chemical probes', True).otherwise(False))
    # Clean rows where control = 1
    .withColumn('control', when(~col('control').contains(1), col('control')))
    .withColumn('control', when(~col('control').contains('2S'), col('control')))
    # Group data and collect sets
    .groupBy('uniprot_id', 'compound_name', 'drugId', 'inchiKey')
    .agg(
        collect_set(
            struct(
                col('source').alias('niceName'),
                col('source_url').alias('url'))
        ).alias('urls'),
        flatten(collect_set(array("control"))).alias('control'), # max size = 1
        collect_set("probesDrugsScore").alias('probesDrugsScore'),
        collect_set("probeMinerScore").alias('probeMinerScore'),
        collect_set("scoreInCells").alias('scoreInCells'),
        collect_set("scoreInOrganisms").alias('scoreInOrganisms'),
        flatten(collect_set(array("actiontype_id"))).alias('mechanismOfAction'),
        flatten(collect_set(array("isHighQuality"))).alias('isHighQuality'),
        collect_set("origin").alias("origin")
    )
    .withColumn('probesDrugsScore', array_max(col('probesDrugsScore')))
    .withColumn('probeMinerScore', array_max(col('probeMinerScore')))
    .withColumn('scoreInCells', array_max(col('scoreInCells')))
    .withColumn('scoreInOrganisms', array_max(col('scoreInOrganisms')))
    .withColumn('mechanismOfAction', expr('filter(mechanismOfAction, x -> x is not null)'))
    .withColumn('control', explode(col('control')))
    .withColumnRenamed('compound_name', 'id')
    .withColumnRenamed('uniprot_id', 'targetFromSourceId')
    .withColumn('urls', array_distinct(col('urls')))
    # Remove reference to High Quality Probes source as this is a subset curated by P&Ds
    # Problem: there are compounds only referenced with High Quality Probes 
    # Solution: remove it if there is already a reference, otherwise reference P&Ds 
    .withColumn('urls', array_except(col('urls'),
                              array(struct(lit('High-quality chemical probes').alias("niceName"), lit(None).cast("string").alias("url")))))
    .withColumn( 
        'urls',
        when(
            size(col('urls')) == 0,
            array(struct(
                lit('Probes & Drugs Portal').alias('niceName'),
                lit('https://www.probes-drugs.org').alias('url')))
        )
        .otherwise(col('urls'))
    )
    # Convert empty arrays into null
    .withColumn('mechanismOfAction', when(size(col('mechanismOfAction')) == 0, lit(None)).otherwise(col('mechanismOfAction')))
    .withColumn('origin', when(size(col('origin')) == 0, lit(None)).otherwise(col('origin')))
    # Transform isHighQuality to keep only True
    .withColumn('isHighQuality', when(array_contains(col('isHighQuality'), True), True).otherwise(False))
    .distinct()
)

data_m.count()
# Out:
# 4192

# %%
data_m.withColumn('url', explode('urls')).filter(col('url.niceName').contains('Drugs')).first()
# Out:
# Row(targetFromSourceId='O00141', id='SGK1-IN-1', drugId=None, inchiKey='DDKHTWASHUKHLD-UHFFFAOYSA-N', urls=[Row(niceName='Probes & Drugs Portal', url='https://www.probes-drugs.org')], control=None, probesDrugsScore='80.0', probeMinerScore='62.0', scoreInCells=None, scoreInOrganisms=None, mechanismOfAction=['inhibitor'], isHighQuality=True, origin=['calculated'], url=Row(niceName='Probes & Drugs Portal', url='https://www.probes-drugs.org'))

# %%
data_m.show(10, False, True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | B2RXH2
#  id                 | IOX1
#  drugId             | null
#  inchiKey           | JGRPKOGHYBAVMW-UHFFFAOYSA-N
#  urls               | [{SGC Probes, http://www.thesgc.org/chemical-probes/IOX1}]
#  control            | null
#  probesDrugsScore   | 20.4
#  probeMinerScore    | 44.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | true
#  origin             | [experimental]
# -RECORD 1-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00141
#  id                 | SGK1-IN-1
#  drugId             | null
#  inchiKey           | DDKHTWASHUKHLD-UHFFFAOYSA-N
#  urls               | [{Probes & Drugs Portal, https://www.probes-drugs.org}]
#  control            | null
#  probesDrugsScore   | 80.0
#  probeMinerScore    | 62.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | [inhibitor]
#  isHighQuality      | true
#  origin             | [calculated]
# -RECORD 2-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00255
#  id                 | MI-2
#  drugId             | null
#  inchiKey           | SRQYLNYQAPCPIR-UHFFFAOYSA-N
#  urls               | [{Nature Chemical Biology Probes, http://www.nature.com/nchembio/chemical_probes.html}]
#  control            | null
#  probesDrugsScore   | 20.0
#  probeMinerScore    | 31.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [experimental]
# -RECORD 3-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00255
#  id                 | canSAR2959399
#  drugId             | null
#  inchiKey           | BTSUNSRQYLVGIS-ADTYUTHVSA-N
#  urls               | [{Chemical Probes.org (legacy), https://new.chemicalprobes.org/?q=canSAR2959399}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | null
#  scoreInCells       | 58.25
#  scoreInOrganisms   | 50.0
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [experimental]
# -RECORD 4-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00257
#  id                 | canSAR979628
#  drugId             | null
#  inchiKey           | UMRRDXVUROEIKJ-JCXBGQGISA-N
#  urls               | [{Chemical Probes.org (legacy), https://new.chemicalprobes.org/?q=canSAR979628}]
#  control            | null
#  probesDrugsScore   | 30.0
#  probeMinerScore    | 67.0
#  scoreInCells       | 66.75
#  scoreInOrganisms   | 0.0
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [experimental]
# -RECORD 5-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070157
#  drugId             | null
#  inchiKey           | IYFKRIWGRGFLBL-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 49.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 6-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070158
#  drugId             | null
#  inchiKey           | NYNANQKQYVAHFV-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 7-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070159
#  drugId             | null
#  inchiKey           | WPDINEQTRUOZHZ-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 8-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070160
#  drugId             | null
#  inchiKey           | GSCKZFSBVHCSKZ-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# -RECORD 9-----------------------------------------------------------------------------------------------------
#  targetFromSourceId | O00311
#  id                 | PD070162
#  drugId             | null
#  inchiKey           | AMSJYRQZMOVVGU-UHFFFAOYSA-N
#  urls               | [{Probe Miner, http://probeminer.icr.ac.uk/#/O00311}]
#  control            | null
#  probesDrugsScore   | 40.0
#  probeMinerScore    | 50.0
#  scoreInCells       | null
#  scoreInOrganisms   | null
#  mechanismOfAction  | null
#  isHighQuality      | false
#  origin             | [calculated]
# only showing top 10 rows

# %%
data_m.coalesce(1).write.json(f'output/{version}/chemicalprobes_v{version}_1')
